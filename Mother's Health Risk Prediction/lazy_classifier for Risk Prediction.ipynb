# %%
# !pip install lazypredict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from lazypredict) (8.1.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.65.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.2.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (3.3.5)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.7.5)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (0.40.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lazypredict) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->lazypredict) (1.16.0)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.12

# %%
import pandas as pd
import numpy as np
import lazypredict
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split

data = pd.read_csv("/content/drive/MyDrive/Thesis/Maternal Health Risk Data Set.csv")
print(data.head())

# Split the data into features (X) and target variable (y)
X = data.drop('RiskLevel', axis=1)
y = data['RiskLevel']

# Convert target labels to numerical values
y.replace({"low risk": 0, "mid risk": 1, "high risk": 2}, inplace=True)
print(y.head())

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=25)

clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80 15.00     98.00         86  high risk
# 1   35         140           90 13.00     98.00         70  high risk
# 2   29          90           70  8.00    100.00         80  high risk
# 3   30         140           85  7.00     98.00         70  high risk
# 4   35         120           60  6.10     98.00         76   low risk
# 0    2
# 1    2
# 2    2
# 3    2
# 4    0
# Name: RiskLevel, dtype: int64
# 100%|██████████| 29/29 [00:05<00:00,  5.59it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# DecisionTreeClassifier             0.84               0.84    None      0.84
# ExtraTreesClassifier               0.83               0.83    None      0.83
# RandomForestClassifier             0.83               0.83    None      0.83
# XGBClassifier                      0.82               0.83    None      0.83
# ExtraTreeClassifier                0.82               0.83    None      0.82
# LGBMClassifier                     0.81               0.82    None      0.82
# BaggingClassifier                  0.80               0.81    None      0.81
# LabelPropagation                   0.79               0.79    None      0.79
# LabelSpreading                     0.79               0.79    None      0.79
# SVC                                0.74               0.73    None      0.72
# NuSVC                              0.73               0.73    None      0.73
# KNeighborsClassifier               0.67               0.68    None      0.68
# RidgeClassifier                    0.68               0.66    None      0.65
# RidgeClassifierCV                  0.68               0.66    None      0.65
# LinearDiscriminantAnalysis         0.67               0.66    None      0.66
# CalibratedClassifierCV             0.67               0.66    None      0.64
# Perceptron                         0.67               0.66    None      0.64
# LinearSVC                          0.67               0.66    None      0.63
# AdaBoostClassifier                 0.65               0.65    None      0.66
# LogisticRegression                 0.66               0.65    None      0.64
# QuadraticDiscriminantAnalysis      0.67               0.65    None      0.64
# NearestCentroid                    0.62               0.63    None      0.62
# GaussianNB                         0.65               0.62    None      0.62
# BernoulliNB                        0.63               0.60    None      0.58
# SGDClassifier                      0.59               0.57    None      0.52
# PassiveAggressiveClassifier        0.56               0.56    None      0.55
# DummyClassifier                    0.41               0.33    None      0.23
#
#                                Time Taken
# Model
# DecisionTreeClassifier               0.03
# ExtraTreesClassifier                 0.29
# RandomForestClassifier               0.24
# XGBClassifier                        2.98
# ExtraTreeClassifier                  0.02
# LGBMClassifier                       0.33
# BaggingClassifier                    0.04
# LabelPropagation                     0.05
# LabelSpreading                       0.06
# SVC                                  0.08
# NuSVC                                0.07
# KNeighborsClassifier                 0.02
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.02
# LinearDiscriminantAnalysis           0.06
# CalibratedClassifierCV               0.35
# Perceptron                           0.02
# LinearSVC                            0.12
# AdaBoostClassifier                   0.13
# LogisticRegression                   0.04
# QuadraticDiscriminantAnalysis        0.04
# NearestCentroid                      0.01
# GaussianNB                           0.02
# BernoulliNB                          0.03
# SGDClassifier                        0.04
# PassiveAggressiveClassifier          0.02
# DummyClassifier                      0.03

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# DecisionTreeClassifier             0.84               0.84    None      0.84
# ExtraTreesClassifier               0.83               0.83    None      0.83
# RandomForestClassifier             0.83               0.83    None      0.83
# XGBClassifier                      0.82               0.83    None      0.83
# ExtraTreeClassifier                0.82               0.83    None      0.82
# LGBMClassifier                     0.81               0.82    None      0.82
# BaggingClassifier                  0.80               0.81    None      0.81
# LabelPropagation                   0.79               0.79    None      0.79
# LabelSpreading                     0.79               0.79    None      0.79
# SVC                                0.74               0.73    None      0.72
# NuSVC                              0.73               0.73    None      0.73
# KNeighborsClassifier               0.67               0.68    None      0.68
# RidgeClassifier                    0.68               0.66    None      0.65
# RidgeClassifierCV                  0.68               0.66    None      0.65
# LinearDiscriminantAnalysis         0.67               0.66    None      0.66
# CalibratedClassifierCV             0.67               0.66    None      0.64
# Perceptron                         0.67               0.66    None      0.64
# LinearSVC                          0.67               0.66    None      0.63
# AdaBoostClassifier                 0.65               0.65    None      0.66
# LogisticRegression                 0.66               0.65    None      0.64
# QuadraticDiscriminantAnalysis      0.67               0.65    None      0.64
# NearestCentroid                    0.62               0.63    None      0.62
# GaussianNB                         0.65               0.62    None      0.62
# BernoulliNB                        0.63               0.60    None      0.58
# SGDClassifier                      0.59               0.57    None      0.52
# PassiveAggressiveClassifier        0.56               0.56    None      0.55
# DummyClassifier                    0.41               0.33    None      0.23
#
#                                Time Taken
# Model
# DecisionTreeClassifier               0.03
# ExtraTreesClassifier                 0.29
# RandomForestClassifier               0.24
# XGBClassifier                        2.98
# ExtraTreeClassifier                  0.02
# LGBMClassifier                       0.33
# BaggingClassifier                    0.04
# LabelPropagation                     0.05
# LabelSpreading                       0.06
# SVC                                  0.08
# NuSVC                                0.07
# KNeighborsClassifier                 0.02
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.02
# LinearDiscriminantAnalysis           0.06
# CalibratedClassifierCV               0.35
# Perceptron                           0.02
# LinearSVC                            0.12
# AdaBoostClassifier                   0.13
# LogisticRegression                   0.04
# QuadraticDiscriminantAnalysis        0.04
# NearestCentroid                      0.01
# GaussianNB                           0.02
# BernoulliNB                          0.03
# SGDClassifier                        0.04
# PassiveAggressiveClassifier          0.02
# DummyClassifier                      0.03

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

boston = datasets.load_boston()
X, y = shuffle(boston.data, boston.target, random_state=13)


offset = int(X.shape[0] * 0.9)

X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# 100%|██████████| 42/42 [00:02<00:00, 14.55it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# SVR                                          0.83       0.88  2.62        0.03
# BaggingRegressor                             0.83       0.88  2.63        0.06
# NuSVR                                        0.82       0.86  2.76        0.04
# RandomForestRegressor                        0.81       0.86  2.79        0.37
# XGBRegressor                                 0.81       0.86  2.79        0.09
# GradientBoostingRegressor                    0.81       0.86  2.84        0.17
# ExtraTreesRegressor                          0.79       0.84  2.98        0.23
# HistGradientBoostingRegressor                0.77       0.83  3.06        0.27
# AdaBoostRegressor                            0.77       0.83  3.06        0.12
# PoissonRegressor                             0.77       0.83  3.11        0.02
# LGBMRegressor                                0.77       0.83  3.11        0.07
# KNeighborsRegressor                          0.77       0.83  3.12        0.01
# DecisionTreeRegressor                        0.65       0.74  3.79        0.01
# MLPRegressor                                 0.65       0.74  3.80        0.61
# HuberRegressor                               0.64       0.74  3.84        0.02
# GammaRegressor                               0.64       0.73  3.88        0.01
# LinearSVR                                    0.62       0.72  3.96        0.01
# RidgeCV                                      0.62       0.72  3.97        0.01
# BayesianRidge                                0.62       0.72  3.97        0.01
# Ridge                                        0.62       0.72  3.97        0.01
# TransformedTargetRegressor                   0.62       0.72  3.97        0.01
# LinearRegression                             0.62       0.72  3.97        0.01
# ElasticNetCV                                 0.62       0.72  3.98        0.07
# LassoCV                                      0.62       0.72  3.98        0.08
# LassoLarsIC                                  0.62       0.72  3.98        0.02
# LassoLarsCV                                  0.62       0.72  3.98        0.03
# Lars                                         0.61       0.72  3.99        0.03
# LarsCV                                       0.61       0.71  4.02        0.09
# SGDRegressor                                 0.60       0.70  4.07        0.01
# TweedieRegressor                             0.59       0.70  4.12        0.01
# GeneralizedLinearRegressor                   0.59       0.70  4.12        0.02
# ElasticNet                                   0.58       0.69  4.16        0.01
# Lasso                                        0.54       0.66  4.35        0.01
# RANSACRegressor                              0.53       0.65  4.41        0.07
# OrthogonalMatchingPursuitCV                  0.45       0.59  4.78        0.03
# PassiveAggressiveRegressor                   0.37       0.54  5.09        0.02
# GaussianProcessRegressor                     0.23       0.43  5.65        0.05
# OrthogonalMatchingPursuit                    0.16       0.38  5.89        0.02
# ExtraTreeRegressor                           0.08       0.32  6.17        0.01
# DummyRegressor                              -0.38      -0.02  7.56        0.01
# LassoLars                                   -0.38      -0.02  7.56        0.01
# KernelRidge                                -11.50      -8.25 22.74        0.05

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# SVR                                          0.83       0.88  2.62        0.03
# BaggingRegressor                             0.83       0.88  2.63        0.06
# NuSVR                                        0.82       0.86  2.76        0.04
# RandomForestRegressor                        0.81       0.86  2.79        0.37
# XGBRegressor                                 0.81       0.86  2.79        0.09
# GradientBoostingRegressor                    0.81       0.86  2.84        0.17
# ExtraTreesRegressor                          0.79       0.84  2.98        0.23
# HistGradientBoostingRegressor                0.77       0.83  3.06        0.27
# AdaBoostRegressor                            0.77       0.83  3.06        0.12
# PoissonRegressor                             0.77       0.83  3.11        0.02
# LGBMRegressor                                0.77       0.83  3.11        0.07
# KNeighborsRegressor                          0.77       0.83  3.12        0.01
# DecisionTreeRegressor                        0.65       0.74  3.79        0.01
# MLPRegressor                                 0.65       0.74  3.80        0.61
# HuberRegressor                               0.64       0.74  3.84        0.02
# GammaRegressor                               0.64       0.73  3.88        0.01
# LinearSVR                                    0.62       0.72  3.96        0.01
# RidgeCV                                      0.62       0.72  3.97        0.01
# BayesianRidge                                0.62       0.72  3.97        0.01
# Ridge                                        0.62       0.72  3.97        0.01
# TransformedTargetRegressor                   0.62       0.72  3.97        0.01
# LinearRegression                             0.62       0.72  3.97        0.01
# ElasticNetCV                                 0.62       0.72  3.98        0.07
# LassoCV                                      0.62       0.72  3.98        0.08
# LassoLarsIC                                  0.62       0.72  3.98        0.02
# LassoLarsCV                                  0.62       0.72  3.98        0.03
# Lars                                         0.61       0.72  3.99        0.03
# LarsCV                                       0.61       0.71  4.02        0.09
# SGDRegressor                                 0.60       0.70  4.07        0.01
# TweedieRegressor                             0.59       0.70  4.12        0.01
# GeneralizedLinearRegressor                   0.59       0.70  4.12        0.02
# ElasticNet                                   0.58       0.69  4.16        0.01
# Lasso                                        0.54       0.66  4.35        0.01
# RANSACRegressor                              0.53       0.65  4.41        0.07
# OrthogonalMatchingPursuitCV                  0.45       0.59  4.78        0.03
# PassiveAggressiveRegressor                   0.37       0.54  5.09        0.02
# GaussianProcessRegressor                     0.23       0.43  5.65        0.05
# OrthogonalMatchingPursuit                    0.16       0.38  5.89        0.02
# ExtraTreeRegressor                           0.08       0.32  6.17        0.01
# DummyRegressor                              -0.38      -0.02  7.56        0.01
# LassoLars                                   -0.38      -0.02  7.56        0.01
# KernelRidge                                -11.50      -8.25 22.74        0.05

# %%
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male 22.00  ...   NaN  Southampton     no  False
# 1         1       1  female 38.00  ...     C    Cherbourg    yes  False
# 2         1       3  female 26.00  ...   NaN  Southampton    yes   True
# 3         1       1  female 35.00  ...     C  Southampton    yes  False
# 4         0       3    male 35.00  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
X=df.drop('survived',axis=1)
y=df.iloc[:,0]

# %%
X.head()
# Out:
#    pclass     sex   age  sibsp  ...  deck  embark_town alive  alone
# 0       3    male 22.00      1  ...   NaN  Southampton    no  False
# 1       1  female 38.00      1  ...     C    Cherbourg   yes  False
# 2       3  female 26.00      0  ...   NaN  Southampton   yes   True
# 3       1  female 35.00      1  ...     C  Southampton   yes  False
# 4       3    male 35.00      0  ...   NaN  Southampton    no   True
#
# [5 rows x 14 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.25,random_state =123)

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=False, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
#  14%|█▍        | 4/29 [00:00<00:01, 20.90it/s]
# CategoricalNB model failed to execute
# Negative values in data passed to CategoricalNB (input X)
# 100%|██████████| 29/29 [00:01<00:00, 19.68it/s]
# StackingClassifier model failed to execute
# __init__() missing 1 required positional argument: 'estimators'

# %%
print(models)
# Out:
#                                Accuracy  ...  Time Taken
# Model                                    ...
# AdaBoostClassifier                 1.00  ...        0.03
# BaggingClassifier                  1.00  ...        0.04
# XGBClassifier                      1.00  ...        0.06
# SVC                                1.00  ...        0.06
# SGDClassifier                      1.00  ...        0.04
# RidgeClassifierCV                  1.00  ...        0.04
# RidgeClassifier                    1.00  ...        0.04
# RandomForestClassifier             1.00  ...        0.20
# Perceptron                         1.00  ...        0.02
# PassiveAggressiveClassifier        1.00  ...        0.03
# LogisticRegression                 1.00  ...        0.05
# LinearSVC                          1.00  ...        0.07
# GaussianNB                         1.00  ...        0.04
# ExtraTreesClassifier               1.00  ...        0.15
# ExtraTreeClassifier                1.00  ...        0.02
# DecisionTreeClassifier             1.00  ...        0.02
# CalibratedClassifierCV             1.00  ...        0.10
# BernoulliNB                        1.00  ...        0.02
# LGBMClassifier                     1.00  ...        0.05
# NuSVC                              0.99  ...        0.07
# KNeighborsClassifier               0.99  ...        0.03
# LabelSpreading                     0.98  ...        0.07
# LabelPropagation                   0.98  ...        0.06
# NearestCentroid                    0.92  ...        0.04
# LinearDiscriminantAnalysis         0.84  ...        0.04
# DummyClassifier                    0.55  ...        0.02
# QuadraticDiscriminantAnalysis      0.62  ...        0.02
#
# [27 rows x 5 columns]

# %%
models
# Out:
#                                Accuracy  ...  Time Taken
# Model                                    ...
# AdaBoostClassifier                 1.00  ...        0.03
# BaggingClassifier                  1.00  ...        0.04
# XGBClassifier                      1.00  ...        0.06
# SVC                                1.00  ...        0.06
# SGDClassifier                      1.00  ...        0.04
# RidgeClassifierCV                  1.00  ...        0.04
# RidgeClassifier                    1.00  ...        0.04
# RandomForestClassifier             1.00  ...        0.20
# Perceptron                         1.00  ...        0.02
# PassiveAggressiveClassifier        1.00  ...        0.03
# LogisticRegression                 1.00  ...        0.05
# LinearSVC                          1.00  ...        0.07
# GaussianNB                         1.00  ...        0.04
# ExtraTreesClassifier               1.00  ...        0.15
# ExtraTreeClassifier                1.00  ...        0.02
# DecisionTreeClassifier             1.00  ...        0.02
# CalibratedClassifierCV             1.00  ...        0.10
# BernoulliNB                        1.00  ...        0.02
# LGBMClassifier                     1.00  ...        0.05
# NuSVC                              0.99  ...        0.07
# KNeighborsClassifier               0.99  ...        0.03
# LabelSpreading                     0.98  ...        0.07
# LabelPropagation                   0.98  ...        0.06
# NearestCentroid                    0.92  ...        0.04
# LinearDiscriminantAnalysis         0.84  ...        0.04
# DummyClassifier                    0.55  ...        0.02
# QuadraticDiscriminantAnalysis      0.62  ...        0.02
#
# [27 rows x 5 columns]
